# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# Loading Data

# %%
import pickle as pkl
with open("version_1_joined_and_grouped.pkl", "rb") as f:
    version_1_data = pkl.load(f)

print(version_1_data.shape)
version_1_data.head()
# Out:
# (223903, 52)
#            uid  no_of_loans_first  loan_amount_sum  loan_amount_mean  \
# 0  AAA09044550                  2       277245.000        138622.500
# 1  AAA10545297                  1        80996.445         80996.445
# 2  AAA14112888                  1        43771.500         43771.500
# 3  AAA20326915                  8       591597.000         73949.625
# 4  AAA31604840                  5      1591960.500        318392.100
#
#    amount_overdue_sum  amount_overdue_mean  loan_run_sum  loan_run_mean  \
# 0                 0.0                  0.0          1022        511.000
# 1                 0.0                  0.0           913        913.000
# 2                 0.0                  0.0            92         92.000
# 3                 0.0                  0.0          6803        850.375
# 4                 0.0                  0.0          4600        920.000
#
#    loan_closed_sum  no_of_times_late_sum  ...  \
# 0                2                     3  ...
# ...

# %% [markdown]
# ## EDA

# %% [markdown]
# ## Histograms for various numerical columns

# %%
numerical_columns = ['no_of_loans_first', 'loan_amount_sum', 'loan_amount_mean',
       'amount_overdue_sum', 'amount_overdue_mean', 'loan_run_sum',
       'loan_run_mean', 'loan_closed_sum', 'no_of_times_late_sum',
       'no_of_times_late_mean', 'total_late_days_sum', 'total_late_days_mean',
       'max_late_days_max', 'largest_consecutive_late_max']


for_sns = ['no_of_loans_first', 'loan_amount_sum', 'loan_amount_mean',
       'amount_overdue_sum', 'loan_run_mean', 'loan_closed_sum',
       'no_of_times_late_mean', 'total_late_days_sum', 'total_late_days_mean',
       'max_late_days_max', 'largest_consecutive_late_max', 'TARGET']

sns.pairplot(version_1_data[for_sns], hue="TARGET")

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 1
# ----> 1 sn
#
# NameError: name 'sn' is not defined
